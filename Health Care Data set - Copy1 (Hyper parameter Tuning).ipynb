# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# ![2.png](attachment:2.png)

# %% [markdown]
# ![3.png](attachment:3.png)

# %%
#Import the necessary library.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#Import the dataset.
df = pd.read_csv('health care diabetes.csv')
print(df.shape)
df.head()
# Out:
# (768, 9)
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# ##### Univariate analysis on the Independent Variables and Target variable.

# %%
#4. Count plot of Outcome (Target variable.)
sns.countplot(data = df, x = 'Outcome' )
plt.title("Count plot of Outcome.")
plt.show()
print("\n")
print(df['Outcome'].value_counts())
# Out:
# 0    500
# 1    268
# Name: Outcome, dtype: int64

# %%
#Count plot of Pregnancies.
sns.countplot(data = df, x = 'Pregnancies')
plt.title("Count plot of Pregnancies")
plt.show()

# %%
sns.histplot(data = df, x = 'Glucose')
plt.title("Histogram of Glucose level")
plt.show()

# %%
sns.histplot(data = df, x = 'BloodPressure')
plt.title("Histogram of BloodPressure")
plt.show()

# %%
sns.histplot(data = df, x = 'SkinThickness')
plt.title("Histogram of SkinThickness")
plt.show()

# %%
sns.histplot(data = df, x = 'Insulin')
plt.title("Histogram of Insulin")
plt.show()

# %%
sns.histplot(data = df, x = 'BMI', color = 'purple')
plt.title("Histogram of BMI")
plt.show()

# %%
sns.histplot(data = df, x = 'DiabetesPedigreeFunction', color = 'red')
plt.title("Histogram of DiabetesPedigreeFunction")
plt.show()

# %%
sns.histplot(data = df, x = 'Age', color = 'Green')
plt.title("Histogram of Age")
plt.show()

# %%
#Replace 0 in column Glucose, Blood Pressure, Insulin, Skin Thickness and BMI with null values.
df['Glucose'] = df['Glucose'].replace(0, np.nan)
df['BloodPressure'] = df['BloodPressure'].replace(0, np.nan)
df['Insulin'] = df['Insulin'].replace(0, np.nan)
df['SkinThickness'] = df['SkinThickness'].replace(0, np.nan)
df['BMI'] = df['BMI'].replace(0, np.nan)

# %%
#Check for the number of null values in the datset.
df.isna().sum()
# Out:
# Pregnancies                   0
# Glucose                       5
# BloodPressure                35
# SkinThickness               227
# Insulin                     374
# BMI                          11
# DiabetesPedigreeFunction      0
# Age                           0
# Outcome                       0
# dtype: int64

# %%
#Fill null values with median in column Glucose, Blood Pressure, Insulin, Skin Thickness and BMI with null values.
df['Glucose'] = df['Glucose'].fillna(df['Glucose'].median())
df['BloodPressure'] = df['BloodPressure'].fillna(df['BloodPressure'].median())
df['Insulin'] = df['Insulin'].fillna(df['Insulin'].median())
df['SkinThickness'] = df['SkinThickness'].fillna(df['SkinThickness'].median())
df['BMI'] = df['BMI'].fillna(df['BMI'].median())

# %%
#Check for the number of null values in the datset.
df.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
#The data set after missing values treatment.
print(df.head())
print("\n")
print(df.info())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0    125.0  33.6
# 1            1     85.0           66.0           29.0    125.0  26.6
# 2            8    183.0           64.0           29.0    125.0  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    float64
#  2   BloodPressure             768 non-null    float64
#  3   SkinThickness             768 non-null    float64
#  4   Insulin                   768 non-null    float64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(6), int64(3)
# memory usage: 54.1 KB
# None

# %%
#Check for the outliers in the datset.
for col in df.columns:
    plt.boxplot(df[col])
    plt.title("Box plot of {}".format(col))
    plt.show()

# %% [markdown]
# #### Bivariate Analysis of independent variables with Target variable.

# %%
#Pregnancies variation with Outcome.
sns.countplot(data = df, x = 'Pregnancies', hue = 'Outcome')
plt.title("Count plot of Pregnancies with Outcome.")
plt.show()

# %% [markdown]
# #### Infrences from the above plot:
#  1. A Person definetly have diabetes if no of pregnancies is greater than 6.
#  2. Probablit of diabetes is less if no of preganancies person has/has is  1 or 2.
#  3. Count of the pateient has pregnancies is more in range 1 - 5.
#  4. Indpenedent variable pregnancies is impacting target variable Outcome.

# %%
#Glucose variation with Outcome.
sns.violinplot(data = df, x = 'Outcome', y = 'Glucose')
plt.title("Violin plot of Glucose with outcome")
plt.show()

# %%
#BloodPressure variation with Outcome.
sns.violinplot(data = df, x = 'Outcome', y = 'BloodPressure')
plt.title("Violin plot of BloodPressure with Outcome")
plt.show()

# %%
#SkinThickness variation with Outcome.
sns.violinplot(data = df, x = 'Outcome', y = 'SkinThickness')
plt.title("Violin plot of SkinThickness with Outcome")
plt.show()

# %%
#Insulin variation with Outcome.
sns.violinplot(data = df, x = 'Outcome', y = 'Insulin')
plt.title("Violen plot of Insulin with Outcome")
plt.show()

# %%
#BMI variation with Outcome.
sns.violinplot(data = df, x = 'Outcome', y = 'BMI')
plt.title("Violen plot of BMI with Outcome")
plt.show()

# %%
#DiabetesPedigreeFunction variation with Outcome.
sns.violinplot(data = df, x = 'Outcome', y = 'DiabetesPedigreeFunction')
plt.title("Violen plot of DiabetesPedigreeFunction with Outcome")
plt.show()

# %%
#Age variation with Outcome.
sns.violinplot(data = df, x = 'Outcome', y = 'Age')
plt.title("Violen plot of Age with Outcome")
plt.show()

# %%
sns.pairplot(data = df, x_vars = ['Pregnancies', 'Glucose', 'BloodPressure'], y_vars = 'Outcome', kind = 'scatter')
plt.title("Scatter plot of Pregnancies, Glucose, BloodPressure with outcome")
plt.show()

# %%
sns.pairplot(data = df, x_vars = ['SkinThickness', 'Insulin', 'BMI'], y_vars = 'Outcome', kind = 'scatter')
plt.title("Scatter plot of SkinThickness, Insulin, BMI with outcome")
plt.show()

# %%
sns.pairplot(data = df, x_vars = ['DiabetesPedigreeFunction', 'Age'], y_vars = 'Outcome', kind = 'scatter')
plt.title("Scatter plot of DiabetesPedigreeFunction, Age with outcome")
plt.show()

# %%
#Correlation Analysis using a heatmap.
plt.figure(figsize = (10,8))
sns.heatmap(data = df.corr(), annot = True, square = True)
plt.show()

# %% [markdown]
# #### Infrences:
# 1. Glucose level of the patient shows stong positive correlation(+0.49) with Outcome.
# 2. Age and Pregnancies shows strong positive correlation(+0.54).
# 3. Skin Thickness and BMI shows strong positive correlation(+0.54).
# 4. Insulin level and Gluscose shows a positive correlation(+0.42).
# 5. All variables are positively correlated with each other.

# %% [markdown]
# ### Model building

# %% [markdown]
# The Dateset contain labeled independent variables (or attributes) and decrete taget variables as:
#
# Independent variables:
#  1. Pregnancies
#  2. Glucose
#  3. BloodPressure
#  4. SkinThickness
#  5. Insulin
#  6. BMI
#  7. DiabetesPedigreeFunction
#  8. Age
#
# Target variable:
#    1. Outocme
#
# Thus, the model will be supervised classification model.

# %%
#Split the dataset as inpendepent and dependent variables.
x = df.iloc[:,0:8]
y = df.iloc[:,-1]
print(x.head())
print(y.head())
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6    148.0           72.0           35.0    125.0  33.6
# 1            1     85.0           66.0           29.0    125.0  26.6
# 2            8    183.0           64.0           29.0    125.0  23.3
# 3            1     89.0           66.0           23.0     94.0  28.1
# 4            0    137.0           40.0           35.0    168.0  43.1
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50
# 1                     0.351   31
# 2                     0.672   32
# 3                     0.167   21
# 4                     2.288   33
# 0    1
# 1    0
# 2    1
# 3    0
# 4    1
# Name: Outcome, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
#x_scaled = scaler.fit(x)
x_scaled = scaler.fit_transform(x)
print(x_scaled)
print(x_scaled.shape)
# Out:
# [[ 0.63994726  0.86604475 -0.03198993 ...  0.16661938  0.46849198
#    1.4259954 ]
#  [-0.84488505 -1.20506583 -0.5283186  ... -0.85219976 -0.36506078
#   -0.19067191]
#  [ 1.23388019  2.01666174 -0.69376149 ... -1.33250021  0.60439732
#   -0.10558415]
#  ...
#  [ 0.3429808  -0.02157407 -0.03198993 ... -0.910418   -0.68519336
#   -0.27575966]
#  [-0.84488505  0.14279979 -1.02464727 ... -0.34279019 -0.37110101
#    1.17073215]
#  [-0.84488505 -0.94206766 -0.19743282 ... -0.29912651 -0.47378505
#   -0.87137393]]
# (768, 8)

# %%
#Split the datset in training and testing set.
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_scaled, y ,train_size = 0.9, random_state = 24)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (691, 8)
# (691,)
# (77, 8)
# (77,)

# %%
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
kf = KFold(n_splits = 10, shuffle = True)

# %% [markdown]
# ### 1. Logistic Regression Model

# %%
#Fitting the logistic Regression model.
from sklearn.linear_model import LogisticRegression
model_logis = LogisticRegression()
model_logis.fit(x_train,y_train)
print(model_logis.coef_)
print(model_logis.intercept_)
# Out:
# [[ 0.38424329  1.1826006  -0.11078609  0.02172378 -0.08485285  0.59248795
#    0.27267369  0.16824026]]
# [-0.90386433]

# %%
#Predicting the result of the model.
from sklearn import metrics
predict_test = model_logis.predict(x_test)
predict_train = model_logis.predict(x_train)

# %%
accuracy_test = metrics.accuracy_score(predict_test, y_test)
accuracy_train = metrics.accuracy_score(predict_train, y_train)
print("Accuracy of the training data: {}.".format(accuracy_train))
print("Accuracy of the testing data: {}.".format(accuracy_test))
# Out:
# Accuracy of the training data: 0.7800289435600579.
# Accuracy of the testing data: 0.7012987012987013.

# %%
matrix = metrics.confusion_matrix(y_test,predict_test)
print("Model confusion matrix : {}".format(matrix))
report = metrics.classification_report(y_test,predict_test)
print("Model Classification report")
print(report)
# Out:
# Model confusion matrix : [[42  6]
#  [17 12]]
# Model Classification report
#               precision    recall  f1-score   support
#
#            0       0.71      0.88      0.79        48
#            1       0.67      0.41      0.51        29
#
#     accuracy                           0.70        77
#    macro avg       0.69      0.64      0.65        77
# weighted avg       0.69      0.70      0.68        77

# %%
#AUC ROC Curve.
logistic_roc = metrics.roc_auc_score(y_test, predict_test)
fpr, tpr, threshold = metrics.roc_curve(y_test, predict_test)
plt.figure()
plt.plot(fpr, tpr, label  = 'ROC curve area = %0.2f'% logistic_roc)
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC AUC curve of the Model")
plt.legend(loc = "lower right")
plt.show()

# %%
#K-Fold Cross Validation way.
scores = cross_val_score(model_logis, x_scaled, y, scoring = 'accuracy', cv = kf)
print("Cross validation score: {}".format(scores))
print("\n")
mean_accuracy = cross_val_score(model_logis,x_scaled,y,scoring = 'accuracy',cv = kf).mean()
print("Mean Accuracy :{}.".format(mean_accuracy))
print("\n")
print("The number of CV score used in average: {}".format(len(scores)))
# Out:
# Cross validation score: [0.77922078 0.77922078 0.79220779 0.71428571 0.74025974 0.75324675
#  0.74025974 0.67532468 0.88157895 0.80263158]
#
#
# Mean Accuracy :0.7708988380041012.
#
#
# The number of CV score used in average: 10

# %% [markdown]
# #Hyper parameter Tuning.
# ![Screenshot%202023-10-16%20at%205.17.06%20PM.png](attachment:Screenshot%202023-10-16%20at%205.17.06%20PM.png)

# %%
params = {'solver': ['newton-cg', 'lbfgs', 'liblinear','sag','saga'],
         'penalty': ['None','l1','l2','elasticnet'],
         'C': [100,10,1,0.1,0.01],
         'max_iter': [100,1000,2500,5000]}
params
# Out:
# {'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
#  'penalty': ['None', 'l1', 'l2', 'elasticnet'],
#  'C': [100, 10, 1, 0.1, 0.01],
#  'max_iter': [100, 1000, 2500, 5000]}

# %%
grid = GridSearchCV(model_logis, param_grid = params, refit = True, verbose = 2, cv = kf)
grid
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=True),
#              estimator=LogisticRegression(C=10, penalty='l1',
#                                           solver='liblinear'),
#              param_grid={'C': [100, 10, 1, 0.1, 0.01],
#                          'max_iter': [100, 1000, 2500, 5000],
#                          'penalty': ['None', 'l1', 'l2', 'elasticnet'],
#                          'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag',
#                                     'saga']},
#              verbose=2)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 10 folds for each of 400 candidates, totalling 4000 fits
# [CV] END C=100, max_iter=100, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END ....C=100, max_iter=100, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ....C=100, max_iter=100, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ....C=100, max_iter=100, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ....C=100, max_iter=100, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ....C=100, max_iter=100, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ....C=100, max_iter=100, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ....C=100, max_iter=100, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ....C=100, max_iter=100, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ....C=100, max_iter=100, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ....C=100, max_iter=100, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=None, solver=sag; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=None, solver=sag; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=None, solver=sag; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=None, solver=sag; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=None, solver=sag; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=None, solver=sag; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=None, solver=sag; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=None, solver=sag; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=None, solver=sag; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=None, solver=sag; total time=   0.0s
# [CV] END .....C=100, max_iter=100, penalty=None, solver=saga; total time=   0.0s
# [CV] END .....C=100, max_iter=100, penalty=None, solver=saga; total time=   0.0s
# [CV] END .....C=100, max_iter=100, penalty=None, solver=saga; total time=   0.0s
# [CV] END .....C=100, max_iter=100, penalty=None, solver=saga; total time=   0.0s
# [CV] END .....C=100, max_iter=100, penalty=None, solver=saga; total time=   0.0s
# [CV] END .....C=100, max_iter=100, penalty=None, solver=saga; total time=   0.0s
# [CV] END .....C=100, max_iter=100, penalty=None, solver=saga; total time=   0.0s
# [CV] END .....C=100, max_iter=100, penalty=None, solver=saga; total time=   0.0s
# [CV] END .....C=100, max_iter=100, penalty=None, solver=saga; total time=   0.0s
# [CV] END .....C=100, max_iter=100, penalty=None, solver=saga; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END ........C=100, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END ........C=100, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END ........C=100, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END ........C=100, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END ........C=100, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END ........C=100, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END ........C=100, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END ........C=100, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END ........C=100, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END ........C=100, max_iter=100, penalty=l1, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END .......C=100, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END .......C=100, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END .......C=100, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END .......C=100, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END .......C=100, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END .......C=100, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END .......C=100, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END .......C=100, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END .......C=100, max_iter=100, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END ......C=100, max_iter=100, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ..C=100, max_iter=100, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END ........C=100, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END ........C=100, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END ........C=100, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END ........C=100, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END ........C=100, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END ........C=100, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END ........C=100, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END ........C=100, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END ........C=100, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END ........C=100, max_iter=100, penalty=l2, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END .......C=100, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END .......C=100, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END .......C=100, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END .......C=100, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END .......C=100, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END .......C=100, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END .......C=100, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END .......C=100, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END .......C=100, max_iter=100, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=100, max_iter=100, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END ...C=100, max_iter=1000, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ...C=100, max_iter=1000, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ...C=100, max_iter=1000, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ...C=100, max_iter=1000, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ...C=100, max_iter=1000, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ...C=100, max_iter=1000, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ...C=100, max_iter=1000, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ...C=100, max_iter=1000, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ...C=100, max_iter=1000, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ...C=100, max_iter=1000, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=None, solver=sag; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=None, solver=sag; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=None, solver=sag; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=None, solver=sag; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=None, solver=sag; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=None, solver=sag; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=None, solver=sag; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=None, solver=sag; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=None, solver=sag; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=None, solver=sag; total time=   0.0s
# [CV] END ....C=100, max_iter=1000, penalty=None, solver=saga; total time=   0.0s
# [CV] END ....C=100, max_iter=1000, penalty=None, solver=saga; total time=   0.0s
# [CV] END ....C=100, max_iter=1000, penalty=None, solver=saga; total time=   0.0s
# [CV] END ....C=100, max_iter=1000, penalty=None, solver=saga; total time=   0.0s
# [CV] END ....C=100, max_iter=1000, penalty=None, solver=saga; total time=   0.0s
# [CV] END ....C=100, max_iter=1000, penalty=None, solver=saga; total time=   0.0s
# [CV] END ....C=100, max_iter=1000, penalty=None, solver=saga; total time=   0.0s
# [CV] END ....C=100, max_iter=1000, penalty=None, solver=saga; total time=   0.0s
# [CV] END ....C=100, max_iter=1000, penalty=None, solver=saga; total time=   0.0s
# [CV] END ....C=100, max_iter=1000, penalty=None, solver=saga; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .......C=100, max_iter=1000, penalty=l1, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=1000, penalty=l1, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=1000, penalty=l1, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=1000, penalty=l1, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=1000, penalty=l1, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=1000, penalty=l1, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=1000, penalty=l1, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=1000, penalty=l1, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=1000, penalty=l1, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=1000, penalty=l1, solver=sag; total time=   0.0s
# [CV] END ......C=100, max_iter=1000, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=1000, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=1000, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=1000, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=1000, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=1000, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=1000, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=1000, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=1000, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=1000, penalty=l1, solver=saga; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=1000, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=1000, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .......C=100, max_iter=1000, penalty=l2, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=1000, penalty=l2, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=1000, penalty=l2, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=1000, penalty=l2, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=1000, penalty=l2, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=1000, penalty=l2, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=1000, penalty=l2, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=1000, penalty=l2, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=1000, penalty=l2, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=1000, penalty=l2, solver=sag; total time=   0.0s
# [CV] END ......C=100, max_iter=1000, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=1000, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=1000, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=1000, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=1000, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=1000, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=1000, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=1000, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=1000, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=1000, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=100, max_iter=1000, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=None, solver=newton-cg; total time=   0.0s
# [CV] END ...C=100, max_iter=2500, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ...C=100, max_iter=2500, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ...C=100, max_iter=2500, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ...C=100, max_iter=2500, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ...C=100, max_iter=2500, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ...C=100, max_iter=2500, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ...C=100, max_iter=2500, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ...C=100, max_iter=2500, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ...C=100, max_iter=2500, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END ...C=100, max_iter=2500, penalty=None, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=None, solver=liblinear; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=None, solver=sag; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=None, solver=sag; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=None, solver=sag; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=None, solver=sag; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=None, solver=sag; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=None, solver=sag; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=None, solver=sag; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=None, solver=sag; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=None, solver=sag; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=None, solver=sag; total time=   0.0s
# [CV] END ....C=100, max_iter=2500, penalty=None, solver=saga; total time=   0.0s
# [CV] END ....C=100, max_iter=2500, penalty=None, solver=saga; total time=   0.0s
# [CV] END ....C=100, max_iter=2500, penalty=None, solver=saga; total time=   0.0s
# [CV] END ....C=100, max_iter=2500, penalty=None, solver=saga; total time=   0.0s
# [CV] END ....C=100, max_iter=2500, penalty=None, solver=saga; total time=   0.0s
# [CV] END ....C=100, max_iter=2500, penalty=None, solver=saga; total time=   0.0s
# [CV] END ....C=100, max_iter=2500, penalty=None, solver=saga; total time=   0.0s
# [CV] END ....C=100, max_iter=2500, penalty=None, solver=saga; total time=   0.0s
# [CV] END ....C=100, max_iter=2500, penalty=None, solver=saga; total time=   0.0s
# [CV] END ....C=100, max_iter=2500, penalty=None, solver=saga; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l1, solver=newton-cg; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=l1, solver=lbfgs; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l1, solver=liblinear; total time=   0.0s
# [CV] END .......C=100, max_iter=2500, penalty=l1, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=2500, penalty=l1, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=2500, penalty=l1, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=2500, penalty=l1, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=2500, penalty=l1, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=2500, penalty=l1, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=2500, penalty=l1, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=2500, penalty=l1, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=2500, penalty=l1, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=2500, penalty=l1, solver=sag; total time=   0.0s
# [CV] END ......C=100, max_iter=2500, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=2500, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=2500, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=2500, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=2500, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=2500, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=2500, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=2500, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=2500, penalty=l1, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=2500, penalty=l1, solver=saga; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l2, solver=newton-cg; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END .....C=100, max_iter=2500, penalty=l2, solver=lbfgs; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .C=100, max_iter=2500, penalty=l2, solver=liblinear; total time=   0.0s
# [CV] END .......C=100, max_iter=2500, penalty=l2, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=2500, penalty=l2, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=2500, penalty=l2, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=2500, penalty=l2, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=2500, penalty=l2, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=2500, penalty=l2, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=2500, penalty=l2, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=2500, penalty=l2, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=2500, penalty=l2, solver=sag; total time=   0.0s
# [CV] END .......C=100, max_iter=2500, penalty=l2, solver=sag; total time=   0.0s
# [CV] END ......C=100, max_iter=2500, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=2500, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=2500, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=2500, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=2500, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=2500, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=2500, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=2500, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=2500, penalty=l2, solver=saga; total time=   0.0s
# [CV] END ......C=100, max_iter=2500, penalty=l2, solver=saga; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=newton-cg; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=lbfgs; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=liblinear; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=100, max_iter=2500, penalty=elasticnet, solver=sag; total time=   0.0s
# ...
# [CV] END C=0.01, max_iter=5000, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=0.01, max_iter=5000, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=0.01, max_iter=5000, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=0.01, max_iter=5000, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=0.01, max_iter=5000, penalty=elasticnet, solver=sag; total time=   0.0s
# [CV] END C=0.01, max_iter=5000, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=0.01, max_iter=5000, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=0.01, max_iter=5000, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=0.01, max_iter=5000, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=0.01, max_iter=5000, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=0.01, max_iter=5000, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=0.01, max_iter=5000, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=0.01, max_iter=5000, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=0.01, max_iter=5000, penalty=elasticnet, solver=saga; total time=   0.0s
# [CV] END C=0.01, max_iter=5000, penalty=elasticnet, solver=saga; total time=   0.0s
# /Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 2600 fits failed out of a total of 4000.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1000 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1160, in fit
#     self._validate_params()
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/utils/_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'penalty' parameter of LogisticRegression must be a str among {'l2', 'none' (deprecated), 'l1', 'elasticnet'} or None. Got 'None' instead.
#
# --------------------------------------------------------------------------------
# 200 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 200 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 200 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 200 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 200 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 200 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 64, in _check_solver
#     raise ValueError(
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
# --------------------------------------------------------------------------------
# 200 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1162, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 54, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 200 fits failed with the following error:
# Traceback (most recent call last):
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 1291, in fit
#     fold_coefs_ = Parallel(n_jobs=self.n_jobs, verbose=self.verbose, prefer=prefer)(
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 1085, in __call__
#     if self.dispatch_one_batch(iterator):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 901, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 819, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/joblib/_parallel_backends.py", line 597, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/joblib/parallel.py", line 288, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/utils/parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/linear_model/_logistic.py", line 521, in _logistic_regression_path
#     alpha = (1.0 / C) * (1 - l1_ratio)
#                          ~~^~~~~~~~~~
# TypeError: unsupported operand type(s) for -: 'int' and 'NoneType'
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /Users/mht/anaconda3/lib/python3.11/site-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan 0.77714286        nan 0.77714286 0.77714286 0.77714286
#  0.77714286 0.77714286 0.77714286        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.77714286        nan 0.77714286
#  0.77714286 0.77714286 0.77714286 0.77714286 0.77714286        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan 0.77714286
#         nan 0.77714286 0.77714286 0.77714286 0.77714286 0.77714286
#  0.77714286        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.77714286        nan 0.77714286 0.77714286 0.77714286
#  0.77714286 0.77714286 0.77714286        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.77714286        nan 0.77714286
#  0.77714286 0.77714286 0.77714286 0.77714286 0.77714286        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan 0.77714286
#         nan 0.77859213 0.77714286 0.77714286 0.77714286 0.77714286
#  0.77714286        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.77714286        nan 0.77859213 0.77714286 0.77714286
#  0.77714286 0.77714286 0.77714286        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.77714286        nan 0.77859213
#  0.77714286 0.77714286 0.77714286 0.77714286 0.77714286        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan 0.7800207
#         nan 0.7800207  0.77714286 0.77714286 0.77714286 0.77714286
#  0.77714286        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.7800207         nan 0.7800207  0.77714286 0.77714286
#  0.77714286 0.77714286 0.77714286        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.7800207         nan 0.7800207
#  0.77714286 0.77714286 0.77714286 0.77714286 0.77714286        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan 0.7800207
#         nan 0.7800207  0.77714286 0.77714286 0.77714286 0.77714286
#  0.77714286        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.77424431        nan 0.77424431 0.77571429 0.77571429
#  0.77426501 0.77571429 0.77571429        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.77424431        nan 0.77424431
#  0.77571429 0.77571429 0.77426501 0.77571429 0.77571429        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan 0.77424431
#         nan 0.77424431 0.77571429 0.77571429 0.77426501 0.77571429
#  0.77571429        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.77424431        nan 0.77424431 0.77571429 0.77571429
#  0.77426501 0.77571429 0.77571429        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.70612836        nan 0.70178054
#  0.77426501 0.77426501 0.76559006 0.77426501 0.77426501        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan 0.70612836
#         nan 0.70178054 0.77426501 0.77426501 0.76559006 0.77426501
#  0.77426501        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan 0.70612836        nan 0.70178054 0.77426501 0.77426501
#  0.76559006 0.77426501 0.77426501        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan 0.70612836        nan 0.70178054
#  0.77426501 0.77426501 0.76559006 0.77426501 0.77426501        nan
#         nan        nan        nan        nan]
#   warnings.warn(
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=True),
#              estimator=LogisticRegression(C=10, penalty='l1',
#                                           solver='liblinear'),
#              param_grid={'C': [100, 10, 1, 0.1, 0.01],
#                          'max_iter': [100, 1000, 2500, 5000],
#                          'penalty': ['None', 'l1', 'l2', 'elasticnet'],
#                          'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag',
#                                     'saga']},
#              verbose=2)

# %%
grid.best_params_
# Out:
# {'C': 1, 'max_iter': 100, 'penalty': 'l1', 'solver': 'liblinear'}

# %%
#Fitting the logistic Regression model.
from sklearn.linear_model import LogisticRegression
model_logis = LogisticRegression(C = 1, penalty = 'l1', solver = 'liblinear', max_iter = 100)
model_logis.fit(x_train,y_train)
print(model_logis.coef_)
print(model_logis.intercept_)
# Out:
# [[ 0.3795358   1.17719805 -0.09459245  0.01087098 -0.07452397  0.58502088
#    0.26449614  0.15682494]]
# [-0.89050507]

# %%
#Predicting the result of the model.
from sklearn import metrics
predict_test = model_logis.predict(x_test)
predict_train = model_logis.predict(x_train)

# %%
accuracy_test = metrics.accuracy_score(predict_test, y_test)
accuracy_train = metrics.accuracy_score(predict_train, y_train)
print("Accuracy of the training data: {}.".format(accuracy_train))
print("Accuracy of the testing data: {}.".format(accuracy_test))
# Out:
# Accuracy of the training data: 0.7800289435600579.
# Accuracy of the testing data: 0.7012987012987013.

# %%
#K-Fold Cross Validation way.
scores = cross_val_score(model_logis, x_scaled, y, scoring = 'accuracy', cv = kf)
print("Cross validation score: {}".format(scores))
print("\n")
mean_accuracy = cross_val_score(model_logis,x_scaled,y,scoring = 'accuracy',cv = kf).mean()
print("Mean Accuracy :{}.".format(mean_accuracy))
print("\n")
print("The number of CV score used in average: {}".format(len(scores)))
# Out:
# Cross validation score: [0.79220779 0.77922078 0.67532468 0.74025974 0.83116883 0.74025974
#  0.80519481 0.75324675 0.77631579 0.80263158]
#
#
# Mean Accuracy :0.772095010252905.
#
#
# The number of CV score used in average: 10

# %% [markdown]
# ### 2. Descision Tree Model

# %%
#Fitting Descision Tree Model.
from sklearn.tree import DecisionTreeClassifier
model_tree = DecisionTreeClassifier(criterion = 'entropy')
model_tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
#Predict the outcome.
from sklearn import metrics
predict_test = model_tree.predict(x_test)
predict_train = model_tree.predict(x_train)
accuracy_test = metrics.accuracy_score(y_test,predict_test)
accuracy_train = metrics.accuracy_score(y_train,predict_train)
print("Training data accuracy: {}".format(accuracy_train))
print("Testing data accuracy: {}".format(accuracy_test))
# Out:
# Training data accuracy: 1.0
# Testing data accuracy: 0.6753246753246753

# %%
#Generate the calssifaction report and confusion matrix.
matrix = metrics.confusion_matrix(y_test,predict_test)
print("Confusion matrix of the model: ")
print(matrix)
print("\n")
print("Classification report of the model: ")
report = metrics.classification_report(y_test,predict_test)
print(report)
# Out:
# Confusion matrix of the model:
# [[37 11]
#  [14 15]]
#
#
# Classification report of the model:
#               precision    recall  f1-score   support
#
#            0       0.73      0.77      0.75        48
#            1       0.58      0.52      0.55        29
#
#     accuracy                           0.68        77
#    macro avg       0.65      0.64      0.65        77
# weighted avg       0.67      0.68      0.67        77

# %%
#ROC - AUC way.
roc_tree = metrics.roc_auc_score(y_test,predict_test)
fpr, tpr, threshold = metrics.roc_curve(y_test,predict_test)
plt.plot(fpr, tpr, label = "ROC curve area = %0.2f"% roc_tree)
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC AUC curve of the Model")
plt.legend(loc = 'lower right')
plt.show()

# %%
#K-Fold way.
CV_score = cross_val_score(model_tree, x_scaled, y, cv = kf)
print("Cross validation score: {}".format(CV_score))
print("\n")
CV_accuracy = cross_val_score(model_tree, x_scaled, y, cv = kf).mean()
print("Mean CV accuracy: {}".format(CV_accuracy))
print("\n")
print("The number of CV score used in average: {}".format(len(CV_score)))
# Out:
# Cross validation score: [0.79220779 0.76623377 0.66233766 0.66233766 0.72727273 0.7012987
#  0.66233766 0.71428571 0.78947368 0.72368421]
#
#
# Mean CV accuracy: 0.700563909774436
#
#
# The number of CV score used in average: 10

# %% [markdown]
# #### 3. Random Forest Model

# %%
#Fitting the Random forest Model.
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators = 10)
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=10)

# %%
#Predict the outcome.
from sklearn import metrics
predict_test = model.predict(x_test)
predict_train = model.predict(x_train)
accuracy_test = metrics.accuracy_score(y_test,predict_test)
accuracy_train = metrics.accuracy_score(y_train,predict_train)
print("Training data accuracy: {}".format(accuracy_train))
print("Testing data accuracy: {}".format(accuracy_test))
# Out:
# Training data accuracy: 0.9826338639652678
# Testing data accuracy: 0.7402597402597403

# %%
#Generate the calssifaction report and confusion matrix.
matrix = metrics.confusion_matrix(y_test,predict_test)
print("Confusion matrix of the model: ")
print(matrix)
print("\n")
print("Classification report of the model: ")
report = metrics.classification_report(y_test,predict_test)
print(report)
# Out:
# Confusion matrix of the model:
# [[42  6]
#  [14 15]]
#
#
# Classification report of the model:
#               precision    recall  f1-score   support
#
#            0       0.75      0.88      0.81        48
#            1       0.71      0.52      0.60        29
#
#     accuracy                           0.74        77
#    macro avg       0.73      0.70      0.70        77
# weighted avg       0.74      0.74      0.73        77

# %%
#ROC - AUC way.
roc_tree = metrics.roc_auc_score(y_test,predict_test)
fpr, tpr, threshold = metrics.roc_curve(y_test,predict_test)
plt.plot(fpr, tpr, label = "ROC curve area = %0.2f"% roc_tree)
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC AUC curve of the Model")
plt.legend(loc = 'lower right')
plt.show()

# %%
#K-Fold way.
CV_score = cross_val_score(model, x_scaled, y, cv = kf)
print("Cross validation score: {}".format(CV_score))
print("\n")
CV_accuracy = cross_val_score(model, x_scaled, y, cv = kf).mean()
print("Mean CV accuracy: {}".format(CV_accuracy))
print("\n")
print("The number of CV score used in average: {}".format(len(CV_score)))
# Out:
# Cross validation score: [0.74025974 0.75324675 0.76623377 0.85714286 0.7012987  0.7012987
#  0.64935065 0.74025974 0.78947368 0.76315789]
#
#
# Mean CV accuracy: 0.735663021189337
#
#
# The number of CV score used in average: 10

# %% [markdown]
# #### 4. Naive Bayes Model

# %%
#Fitting Naive baye's Model.
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(x_train,y_train)
# Out:
# GaussianNB()

# %%
#Predict the outcome.
from sklearn import metrics
predict_test = model.predict(x_test)
predict_train = model.predict(x_train)
accuracy_test = metrics.accuracy_score(y_test,predict_test)
accuracy_train = metrics.accuracy_score(y_train,predict_train)
print("Training data accuracy: {}".format(accuracy_train))
print("Testing data accuracy: {}".format(accuracy_test))
# Out:
# Training data accuracy: 0.7539797395079595
# Testing data accuracy: 0.7532467532467533

# %%
#Generate the calssifaction report and confusion matrix.
matrix = metrics.confusion_matrix(y_test,predict_test)
print("Confusion matrix of the model: ")
print(matrix)
print("\n")
print("Classification report of the model: ")
report = metrics.classification_report(y_test,predict_test)
print(report)
# Out:
# Confusion matrix of the model:
# [[42  6]
#  [13 16]]
#
#
# Classification report of the model:
#               precision    recall  f1-score   support
#
#            0       0.76      0.88      0.82        48
#            1       0.73      0.55      0.63        29
#
#     accuracy                           0.75        77
#    macro avg       0.75      0.71      0.72        77
# weighted avg       0.75      0.75      0.74        77

# %%
#ROC - AUC way.
roc_tree = metrics.roc_auc_score(y_test,predict_test)
fpr, tpr, threshold = metrics.roc_curve(y_test,predict_test)
plt.plot(fpr, tpr, label = "ROC curve area = %0.2f"% roc_tree)
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC AUC curve of the Model")
plt.legend(loc = 'lower right')
plt.show()

# %%
#K-Fold way.
CV_score = cross_val_score(model, x_scaled, y, cv = kf)
print("Cross validation score: {}".format(CV_score))
print("\n")
CV_accuracy = cross_val_score(model, x_scaled, y, cv = kf).mean()
print("Mean CV accuracy: {}".format(CV_accuracy))
print("\n")
print("The number of CV score used in average: {}".format(len(CV_score)))
# Out:
# Cross validation score: [0.80519481 0.81818182 0.75324675 0.55844156 0.72727273 0.77922078
#  0.76623377 0.75324675 0.76315789 0.76315789]
#
#
# Mean CV accuracy: 0.75134996582365
#
#
# The number of CV score used in average: 10

# %% [markdown]
# ### 5. KNN Model

# %%
#Fitting KNN Model.
from sklearn.neighbors import KNeighborsClassifier
model = KNeighborsClassifier(n_neighbors = 27)
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=27)

# %%
#Predict the outcome.
from sklearn import metrics
predict_test = model.predict(x_test)
predict_train = model.predict(x_train)
accuracy_test = metrics.accuracy_score(y_test,predict_test)
accuracy_train = metrics.accuracy_score(y_train,predict_train)
print("Training data accuracy: {}".format(accuracy_train))
print("Testing data accuracy: {}".format(accuracy_test))
# Out:
# Training data accuracy: 0.7930535455861071
# Testing data accuracy: 0.7012987012987013

# %%
#Generate the calssifaction report and confusion matrix.
matrix = metrics.confusion_matrix(y_test,predict_test)
print("Confusion matrix of the model: ")
print(matrix)
print("\n")
print("Classification report of the model: ")
report = metrics.classification_report(y_test,predict_test)
print(report)
# Out:
# Confusion matrix of the model:
# [[44  4]
#  [19 10]]
#
#
# Classification report of the model:
#               precision    recall  f1-score   support
#
#            0       0.70      0.92      0.79        48
#            1       0.71      0.34      0.47        29
#
#     accuracy                           0.70        77
#    macro avg       0.71      0.63      0.63        77
# weighted avg       0.70      0.70      0.67        77

# %%
#ROC - AUC way.
roc_tree = metrics.roc_auc_score(y_test,predict_test)
fpr, tpr, threshold = metrics.roc_curve(y_test,predict_test)
plt.plot(fpr, tpr, label = "ROC curve area = %0.2f"% roc_tree)
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC AUC curve of the Model")
plt.legend(loc = 'lower right')
plt.show()

# %%
#K-Fold way.
CV_score = cross_val_score(model, x_scaled, y, cv = kf)
print("Cross validation score: {}".format(CV_score))
print("\n")
CV_accuracy = cross_val_score(model, x_scaled, y, cv = kf).mean()
print("Mean CV accuracy: {}".format(CV_accuracy))
print("\n")
print("The number of CV score used in average: {}".format(len(CV_score)))
# Out:
# Cross validation score: [0.76623377 0.81818182 0.75324675 0.75324675 0.74025974 0.79220779
#  0.80519481 0.77922078 0.75       0.72368421]
#
#
# Mean CV accuracy: 0.7525974025974026
#
#
# The number of CV score used in average: 10

# %% [markdown]
# ### 6. SVM Model

# %%
#Fitting the SVM Model.
from sklearn.svm import SVC
model = SVC(kernel = 'sigmoid')
model.fit(x_train,y_train)
# Out:
# SVC(kernel='sigmoid')

# %%
#Predict the outcome.
from sklearn import metrics
predict_test = model.predict(x_test)
predict_train = model.predict(x_train)
accuracy_test = metrics.accuracy_score(y_test,predict_test)
accuracy_train = metrics.accuracy_score(y_train,predict_train)
print("Training data accuracy: {}".format(accuracy_train))
print("Testing data accuracy: {}".format(accuracy_test))
# Out:
# Training data accuracy: 0.8234442836468886
# Testing data accuracy: 0.7012987012987013

# %%
#Generate the calssifaction report and confusion matrix.
matrix = metrics.confusion_matrix(y_test,predict_test)
print("Confusion matrix of the model: ")
print(matrix)
print("\n")
print("Classification report of the model: ")
report = metrics.classification_report(y_test,predict_test)
print(report)
# Out:
# Confusion matrix of the model:
# [[44  4]
#  [19 10]]
#
#
# Classification report of the model:
#               precision    recall  f1-score   support
#
#            0       0.70      0.92      0.79        48
#            1       0.71      0.34      0.47        29
#
#     accuracy                           0.70        77
#    macro avg       0.71      0.63      0.63        77
# weighted avg       0.70      0.70      0.67        77

# %%
#ROC - AUC way.
roc = metrics.roc_auc_score(y_test,predict_test)
fpr, tpr, threshold = metrics.roc_curve(y_test,predict_test)
plt.plot(fpr, tpr, label = "ROC curve area = %0.2f"% roc)
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC AUC curve of the Model")
plt.legend(loc = 'lower right')
plt.show()

# %% [markdown]
# #### Hyperparameter tuning for SVM Model.

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'kernel': ['liner', 'rbf', 'sigmoid', 'poly'],'C':[0.1,1,10,100],'gamma': [10, 1, 0.1, 0.01, 0.001] }
param_grid
# Out:
# {'kernel': ['liner', 'rbf', 'sigmoid', 'poly'],
#  'C': [0.1, 1, 10, 100],
#  'gamma': [10, 1, 0.1, 0.01, 0.001]}

# %%
grid = GridSearchCV(model, param_grid, cv = kf, verbose = 2, refit = True)
grid
# Out:
# GridSearchCV(cv=KFold(n_splits=10, random_state=None, shuffle=True),
#              estimator=SVC(C=1, gamma=0.01, kernel='sigmoid'),
#              param_grid={'C': [0.1, 1, 10, 100],
#                          'gamma': [10, 1, 0.1, 0.01, 0.001],
#                          'kernel': ['liner', 'rbf', 'sigmoid', 'poly']},
#              verbose=2)

# %%
grid.fit(x_train,y_train)
# Out:
# Fitting 10 folds for each of 80 candidates, totalling 800 fits
# [CV] END ......................C=0.1, gamma=10, kernel=liner; total time=   0.0s
# [CV] END ......................C=0.1, gamma=10, kernel=liner; total time=   0.0s
# [CV] END ......................C=0.1, gamma=10, kernel=liner; total time=   0.0s
# [CV] END ......................C=0.1, gamma=10, kernel=liner; total time=   0.0s
# [CV] END ......................C=0.1, gamma=10, kernel=liner; total time=   0.0s
# [CV] END ......................C=0.1, gamma=10, kernel=liner; total time=   0.0s
# [CV] END ......................C=0.1, gamma=10, kernel=liner; total time=   0.0s
# [CV] END ......................C=0.1, gamma=10, kernel=liner; total time=   0.0s
# [CV] END ......................C=0.1, gamma=10, kernel=liner; total time=   0.0s
# [CV] END ......................C=0.1, gamma=10, kernel=liner; total time=   0.0s
# [CV] END ........................C=0.1, gamma=10, kernel=rbf; total time=   0.0s
# [CV] END ........................C=0.1, gamma=10, kernel=rbf; total time=   0.0s
# [CV] END ........................C=0.1, gamma=10, kernel=rbf; total time=   0.0s
# [CV] END ........................C=0.1, gamma=10, kernel=rbf; total time=   0.0s
# [CV] END ........................C=0.1, gamma=10, kernel=rbf; total time=   0.1s
# [CV] END ........................C=0.1, gamma=10, kernel=rbf; total time=   0.1s
# [CV] END ........................C=0.1, gamma=10, kernel=rbf; total time=   0.0s
# [CV] END ........................C=0.1, gamma=10, kernel=rbf; total time=   0.0s
# [CV] END ........................C=0.1, gamma=10, kernel=rbf; total time=   0.0s
# [CV] END ........................C=0.1, gamma=10, kernel=rbf; total time=   0.0s
# [CV] END ....................C=0.1, gamma=10, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=0.1, gamma=10, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=0.1, gamma=10, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=0.1, gamma=10, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=0.1, gamma=10, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=0.1, gamma=10, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=0.1, gamma=10, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=0.1, gamma=10, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=0.1, gamma=10, kernel=sigmoid; total time=   0.0s
# [CV] END ....................C=0.1, gamma=10, kernel=sigmoid; total time=   0.0s
# [CV] END .......................C=0.1, gamma=10, kernel=poly; total time= 3.6min

# %%
grid.best_params_

# %%
#Fitting the SVM Linear Model with best params.
from sklearn.svm import SVC
model = SVC(kernel = 'linear', C = 1, gamma = 10)
model.fit(x_train,y_train)
# Out:
# SVC(C=1, gamma=10, kernel='linear')

# %%
#Predict the outcome.
from sklearn import metrics
predict_test = model.predict(x_test)
predict_train = model.predict(x_train)
accuracy_test = metrics.accuracy_score(y_test,predict_test)
accuracy_train = metrics.accuracy_score(y_train,predict_train)
print("Training data accuracy: {}".format(accuracy_train))
print("Testing data accuracy: {}".format(accuracy_test))
# Out:
# Training data accuracy: 0.7756874095513748
# Testing data accuracy: 0.7012987012987013

# %%
#Fitting the SVM Radial Model with best params.
from sklearn.svm import SVC
model = SVC(kernel = 'rbf', C = 10, gamma = 0.001)
model.fit(x_train,y_train)
# Out:
# SVC(C=10, gamma=0.001)

# %%
#Predict the outcome.
from sklearn import metrics
predict_test = model.predict(x_test)
predict_train = model.predict(x_train)
accuracy_test = metrics.accuracy_score(y_test,predict_test)
accuracy_train = metrics.accuracy_score(y_train,predict_train)
print("Training data accuracy: {}".format(accuracy_train))
print("Testing data accuracy: {}".format(accuracy_test))
# Out:
# Training data accuracy: 0.7785817655571635
# Testing data accuracy: 0.6753246753246753

# %%
#Fitting the SVM Sigmoid Model with best params.
from sklearn.svm import SVC
model = SVC(kernel = 'sigmoid', C = 1, gamma = 0.01)
model.fit(x_train,y_train)
# Out:
# SVC(C=1, gamma=0.01, kernel='sigmoid')

# %%
#Predict the outcome.
from sklearn import metrics
predict_test = model.predict(x_test)
predict_train = model.predict(x_train)
accuracy_test = metrics.accuracy_score(y_test,predict_test)
accuracy_train = metrics.accuracy_score(y_train,predict_train)
print("Training data accuracy: {}".format(accuracy_train))
print("Testing data accuracy: {}".format(accuracy_test))
# Out:
# Training data accuracy: 0.784370477568741
# Testing data accuracy: 0.6753246753246753

# %%
#K-Fold way.
CV_score = cross_val_score(model, x_scaled, y, cv = kf)
print("Cross validation score: {}".format(CV_score))
print("\n")
CV_accuracy = cross_val_score(model, x_scaled, y, cv = kf).mean()
print("Mean CV accuracy: {}".format(CV_accuracy))
print("\n")
print("The number of CV score used in average: {}".format(len(CV_score)))
# Out:
# Cross validation score: [0.76623377 0.71428571 0.67532468 0.80519481 0.75324675 0.77922078
#  0.79220779 0.83116883 0.73684211 0.78947368]
#
#
# Mean CV accuracy: 0.765498974709501
#
#
# The number of CV score used in average: 10

# %% [markdown]
# ### 7. AdaBoost Classifier Model

# %%
#Fitting the Adboost Model.
from sklearn.ensemble import AdaBoostClassifier
model = AdaBoostClassifier(n_estimators = 30, random_state = 24)
model.fit(x_train,y_train)
# Out:
# AdaBoostClassifier(n_estimators=30, random_state=24)

# %%
#Predict the outcome.
from sklearn import metrics
predict_test = model.predict(x_test)
predict_train = model.predict(x_train)
accuracy_test = metrics.accuracy_score(y_test,predict_test)
accuracy_train = metrics.accuracy_score(y_train,predict_train)
print("Training data accuracy: {}".format(accuracy_train))
print("Testing data accuracy: {}".format(accuracy_test))
# Out:
# Training data accuracy: 0.8060781476121563
# Testing data accuracy: 0.7662337662337663

# %%
#Generate the calssifaction report and confusion matrix.
matrix = metrics.confusion_matrix(y_test,predict_test)
print("Confusion matrix of the model: ")
print(matrix)
print("\n")
print("Classification report of the model: ")
report = metrics.classification_report(y_test,predict_test)
print(report)
# Out:
# Confusion matrix of the model:
# [[43  5]
#  [13 16]]
#
#
# Classification report of the model:
#               precision    recall  f1-score   support
#
#            0       0.77      0.90      0.83        48
#            1       0.76      0.55      0.64        29
#
#     accuracy                           0.77        77
#    macro avg       0.76      0.72      0.73        77
# weighted avg       0.77      0.77      0.76        77

# %%
#ROC - AUC way.
roc = metrics.roc_auc_score(y_test,predict_test)
fpr, tpr, threshold = metrics.roc_curve(y_test,predict_test)
plt.plot(fpr, tpr, label = "ROC curve area = %0.2f"% roc)
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC AUC curve of the Model")
plt.legend(loc = 'lower right')
plt.show()

# %%
#K-Fold way.
CV_score = cross_val_score(model, x_scaled, y, cv = kf)
print("Cross validation score: {}".format(CV_score))
print("\n")
CV_accuracy = cross_val_score(model, x_scaled, y, cv = kf).mean()
print("Mean CV accuracy: {}".format(CV_accuracy))
print("\n")
print("The number of CV score used in average: {}".format(len(CV_score)))
# Out:
# Cross validation score: [0.75324675 0.72727273 0.77922078 0.68831169 0.66233766 0.80519481
#  0.71428571 0.76623377 0.82894737 0.80263158]
#
#
# Mean CV accuracy: 0.7487696514012303
#
#
# The number of CV score used in average: 10

# %% [markdown]
# #### 8. XGBoost Classifier Model

# %%
from xgboost import XGBClassifier
model = XGBClassifier()
model.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=None, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
#Predict the outcome.
from sklearn import metrics
predict_test = model.predict(x_test)
predict_train = model.predict(x_train)
accuracy_test = metrics.accuracy_score(y_test,predict_test)
accuracy_train = metrics.accuracy_score(y_train,predict_train)
print("Training data accuracy: {}".format(accuracy_train))
print("Testing data accuracy: {}".format(accuracy_test))
# Out:
# Training data accuracy: 1.0
# Testing data accuracy: 0.7272727272727273

# %%
#Generate the calssifaction report and confusion matrix.
matrix = metrics.confusion_matrix(y_test,predict_test)
print("Confusion matrix of the model: ")
print(matrix)
print("\n")
print("Classification report of the model: ")
report = metrics.classification_report(y_test,predict_test)
print(report)
# Out:
# Confusion matrix of the model:
# [[40  8]
#  [13 16]]
#
#
# Classification report of the model:
#               precision    recall  f1-score   support
#
#            0       0.75      0.83      0.79        48
#            1       0.67      0.55      0.60        29
#
#     accuracy                           0.73        77
#    macro avg       0.71      0.69      0.70        77
# weighted avg       0.72      0.73      0.72        77

# %%
#ROC - AUC way.
roc = metrics.roc_auc_score(y_test,predict_test)
fpr, tpr, threshold = metrics.roc_curve(y_test,predict_test)
plt.plot(fpr, tpr, label = "ROC curve area = %0.2f"% roc)
plt.xlabel("FPR")
plt.ylabel("TPR")
plt.title("ROC AUC curve of the Model")
plt.legend(loc = 'lower right')
plt.show()

# %%
#K-Fold way.
CV_score = cross_val_score(model, x_scaled, y, cv = kf)
print("Cross validation score: {}".format(CV_score))
print("\n")
CV_accuracy = cross_val_score(model, x_scaled, y, cv = kf).mean()
print("Mean CV accuracy: {}".format(CV_accuracy))
print("\n")
print("The number of CV score used in average: {}".format(len(CV_score)))
# Out:
# Cross validation score: [0.75324675 0.67532468 0.76623377 0.7012987  0.7012987  0.75324675
#  0.67532468 0.79220779 0.84210526 0.75      ]
#
#
# Mean CV accuracy: 0.7446855775803145
#
#
# The number of CV score used in average: 10
